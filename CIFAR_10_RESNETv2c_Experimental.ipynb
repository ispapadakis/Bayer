# %% [markdown]
# <a href="https://colab.research.google.com/github/ispapadakis/Bayer/blob/master/CIFAR_10_RESNETv2c_Experimental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Analysis - No Noise
#
# ---
#
# - Architecture: Resnet
# - Data Augmentation: Full range of options as long as no Noise or Cutout (Horizontal Flip, Rotate, Shift, Zoom, Shear, Color Balance)
# - Config B: New LR Schedule
#
# <p> Based On: https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py

# %% [markdown]
# # Load Data and Libraries

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 100
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Model Architecture

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 90:
        lr *= 0.03
    elif epoch > 80:
        lr *= 0.1
    elif epoch > 60:
        lr *= 0.2
    elif epoch > 40:
        lr *= 0.5
    print('Learning rate: ', lr)
    return lr

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   4160        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  8320        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           conv2d_15[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   8256        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  8320        activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           add_4[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   8256        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 128)  8320        activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           add_5[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    16512       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    147584      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 128)    512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 128)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 256)    33024       add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 256)    33024       activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    32896       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 128)    512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 128)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    147584      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    33024       activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           add_7[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 256)    1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    32896       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 128)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 128)    147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 128)    512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 128)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 256)    33024       activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 256)    0           add_8[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 849,002
# Trainable params: 843,786
# Non-trainable params: 5,216
# __________________________________________________________________________________________________
# ResNet29v2

# %%
# save as JSON
pickle.dump( model.to_json(), open( model_type+"_model_json.pkl", "wb" ) )

# %% [markdown]
# # Train Model

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
fname = 'cifar10-resnet{}-best.h5'.format(version)
checkpoint = ModelCheckpoint(filepath=fname,
                             monitor='val_acc', verbose=2, 
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zoom_range=[0.8,1.4],
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    #brightness_range=[.5,1.5], 
    shear_range=15,
    channel_shift_range=0.5,
    fill_mode='nearest'
    )
datagen.fit(x_train)

# %%
# Fit the model on the batches generated by datagen.flow().
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=2*x_train.shape[0]//batch_size,
                    validation_data=(x_test, y_test),
                    epochs=epochs, verbose=2, callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# Learning rate:  0.001
#  - 176s - loss: 2.0862 - acc: 0.4047 - val_loss: 2.1006 - val_acc: 0.4212
#
# Epoch 00001: val_acc improved from -inf to 0.42120, saving model to cifar10-resnet2-best.h5
# Epoch 2/100
# Learning rate:  0.001
#  - 164s - loss: 1.6076 - acc: 0.5420 - val_loss: 1.6905 - val_acc: 0.5673
#
# Epoch 00002: val_acc improved from 0.42120 to 0.56730, saving model to cifar10-resnet2-best.h5
# Epoch 3/100
# Learning rate:  0.001
#  - 164s - loss: 1.4051 - acc: 0.6042 - val_loss: 1.4297 - val_acc: 0.6304
#
# Epoch 00003: val_acc improved from 0.56730 to 0.63040, saving model to cifar10-resnet2-best.h5
# Epoch 4/100
# Learning rate:  0.001
#  - 162s - loss: 1.2722 - acc: 0.6477 - val_loss: 1.2491 - val_acc: 0.6768
#
# Epoch 00004: val_acc improved from 0.63040 to 0.67680, saving model to cifar10-resnet2-best.h5
# Epoch 5/100
# Learning rate:  0.001
#  - 162s - loss: 1.1890 - acc: 0.6743 - val_loss: 1.1092 - val_acc: 0.7181
#
# Epoch 00005: val_acc improved from 0.67680 to 0.71810, saving model to cifar10-resnet2-best.h5
# Epoch 6/100
# Learning rate:  0.001
#  - 163s - loss: 1.1176 - acc: 0.6989 - val_loss: 1.0697 - val_acc: 0.7360
#
# Epoch 00006: val_acc improved from 0.71810 to 0.73600, saving model to cifar10-resnet2-best.h5
# Epoch 7/100
# Learning rate:  0.001
#  - 163s - loss: 1.0721 - acc: 0.7138 - val_loss: 1.0186 - val_acc: 0.7489
#
# Epoch 00007: val_acc improved from 0.73600 to 0.74890, saving model to cifar10-resnet2-best.h5
# Epoch 8/100
# Learning rate:  0.001
#  - 164s - loss: 1.0316 - acc: 0.7262 - val_loss: 1.0543 - val_acc: 0.7491
#
# Epoch 00008: val_acc improved from 0.74890 to 0.74910, saving model to cifar10-resnet2-best.h5
# Epoch 9/100
# Learning rate:  0.001
#  - 164s - loss: 0.9994 - acc: 0.7373 - val_loss: 0.9542 - val_acc: 0.7654
#
# Epoch 00009: val_acc improved from 0.74910 to 0.76540, saving model to cifar10-resnet2-best.h5
# Epoch 10/100
# Learning rate:  0.001
#  - 164s - loss: 0.9738 - acc: 0.7431 - val_loss: 0.7808 - val_acc: 0.8128
#
# Epoch 00010: val_acc improved from 0.76540 to 0.81280, saving model to cifar10-resnet2-best.h5
# Epoch 11/100
# Learning rate:  0.001
#  - 164s - loss: 0.9428 - acc: 0.7544 - val_loss: 0.9670 - val_acc: 0.7672
#
# Epoch 00011: val_acc did not improve from 0.81280
# Epoch 12/100
# Learning rate:  0.001
#  - 164s - loss: 0.9245 - acc: 0.7604 - val_loss: 0.8700 - val_acc: 0.7894
#
# Epoch 00012: val_acc did not improve from 0.81280
# Epoch 13/100
# Learning rate:  0.001
#  - 164s - loss: 0.9094 - acc: 0.7655 - val_loss: 0.9372 - val_acc: 0.7811
#
# Epoch 00013: val_acc did not improve from 0.81280
# Epoch 14/100
# Learning rate:  0.001
#  - 164s - loss: 0.8937 - acc: 0.7703 - val_loss: 0.8568 - val_acc: 0.8016
#
# Epoch 00014: val_acc did not improve from 0.81280
# Epoch 15/100
# Learning rate:  0.001
#  - 164s - loss: 0.8764 - acc: 0.7757 - val_loss: 0.9326 - val_acc: 0.7746
#
# Epoch 00015: val_acc did not improve from 0.81280
# Epoch 16/100
# Learning rate:  0.001
#  - 164s - loss: 0.8626 - acc: 0.7796 - val_loss: 0.7864 - val_acc: 0.8104
#
# Epoch 00016: val_acc did not improve from 0.81280
# Epoch 17/100
# Learning rate:  0.001
#  - 163s - loss: 0.8515 - acc: 0.7845 - val_loss: 0.7469 - val_acc: 0.8319
#
# Epoch 00017: val_acc improved from 0.81280 to 0.83190, saving model to cifar10-resnet2-best.h5
# Epoch 18/100
# Learning rate:  0.001
#  - 164s - loss: 0.8454 - acc: 0.7853 - val_loss: 0.7497 - val_acc: 0.8222
#
# Epoch 00018: val_acc did not improve from 0.83190
# Epoch 19/100
# Learning rate:  0.001
#  - 163s - loss: 0.8287 - acc: 0.7916 - val_loss: 0.8983 - val_acc: 0.7889
#
# Epoch 00019: val_acc did not improve from 0.83190
# Epoch 20/100
# Learning rate:  0.001
#  - 164s - loss: 0.8229 - acc: 0.7928 - val_loss: 0.7876 - val_acc: 0.8202
#
# Epoch 00020: val_acc did not improve from 0.83190
# Epoch 21/100
# Learning rate:  0.001
#  - 164s - loss: 0.8143 - acc: 0.7959 - val_loss: 0.8210 - val_acc: 0.8154
#
# Epoch 00021: val_acc did not improve from 0.83190
# Epoch 22/100
# Learning rate:  0.001
#  - 164s - loss: 0.8052 - acc: 0.7985 - val_loss: 0.6999 - val_acc: 0.8437
#
# Epoch 00022: val_acc improved from 0.83190 to 0.84370, saving model to cifar10-resnet2-best.h5
# Epoch 23/100
# Learning rate:  0.001
#  - 163s - loss: 0.8011 - acc: 0.7993 - val_loss: 0.6995 - val_acc: 0.8451
#
# Epoch 00023: val_acc improved from 0.84370 to 0.84510, saving model to cifar10-resnet2-best.h5
# Epoch 24/100
# Learning rate:  0.001
#  - 164s - loss: 0.7881 - acc: 0.8033 - val_loss: 0.7274 - val_acc: 0.8343
#
# Epoch 00024: val_acc did not improve from 0.84510
# Epoch 25/100
# Learning rate:  0.001
#  - 163s - loss: 0.7872 - acc: 0.8037 - val_loss: 1.0178 - val_acc: 0.7788
#
# Epoch 00025: val_acc did not improve from 0.84510
# Epoch 26/100
# Learning rate:  0.001
#  - 163s - loss: 0.7786 - acc: 0.8079 - val_loss: 0.8377 - val_acc: 0.8023
#
# Epoch 00026: val_acc did not improve from 0.84510
# Epoch 27/100
# Learning rate:  0.001
#  - 163s - loss: 0.7697 - acc: 0.8105 - val_loss: 0.7153 - val_acc: 0.8385
#
# Epoch 00027: val_acc did not improve from 0.84510
# Epoch 28/100
# Learning rate:  0.001
#  - 163s - loss: 0.7688 - acc: 0.8124 - val_loss: 0.6648 - val_acc: 0.8477
#
# Epoch 00028: val_acc improved from 0.84510 to 0.84770, saving model to cifar10-resnet2-best.h5
# Epoch 29/100
# Learning rate:  0.001
#  - 164s - loss: 0.7617 - acc: 0.8121 - val_loss: 0.7289 - val_acc: 0.8330
#
# Epoch 00029: val_acc did not improve from 0.84770
# Epoch 30/100
# Learning rate:  0.001
#  - 163s - loss: 0.7571 - acc: 0.8149 - val_loss: 0.7264 - val_acc: 0.8388
#
# Epoch 00030: val_acc did not improve from 0.84770
# Epoch 31/100
# Learning rate:  0.001
#  - 163s - loss: 0.7481 - acc: 0.8175 - val_loss: 0.6984 - val_acc: 0.8467
#
# Epoch 00031: val_acc did not improve from 0.84770
# Epoch 32/100
# Learning rate:  0.001
#  - 163s - loss: 0.7473 - acc: 0.8169 - val_loss: 0.6352 - val_acc: 0.8611
#
# Epoch 00032: val_acc improved from 0.84770 to 0.86110, saving model to cifar10-resnet2-best.h5
# Epoch 33/100
# Learning rate:  0.001
#  - 164s - loss: 0.7431 - acc: 0.8177 - val_loss: 0.7391 - val_acc: 0.8366
#
# Epoch 00033: val_acc did not improve from 0.86110
# Epoch 34/100
# Learning rate:  0.001
#  - 163s - loss: 0.7363 - acc: 0.8193 - val_loss: 0.6426 - val_acc: 0.8576
#
# Epoch 00034: val_acc did not improve from 0.86110
# Epoch 35/100
# Learning rate:  0.001
#  - 164s - loss: 0.7346 - acc: 0.8197 - val_loss: 0.7274 - val_acc: 0.8405
#
# Epoch 00035: val_acc did not improve from 0.86110
# Epoch 36/100
# Learning rate:  0.001
#  - 163s - loss: 0.7284 - acc: 0.8231 - val_loss: 0.7285 - val_acc: 0.8443
#
# Epoch 00036: val_acc did not improve from 0.86110
# Epoch 37/100
# Learning rate:  0.001
#  - 164s - loss: 0.7293 - acc: 0.8221 - val_loss: 0.7956 - val_acc: 0.8256
#
# Epoch 00037: val_acc did not improve from 0.86110
# Epoch 38/100
# Learning rate:  0.001
#  - 163s - loss: 0.7202 - acc: 0.8256 - val_loss: 0.7604 - val_acc: 0.8305
#
# Epoch 00038: val_acc did not improve from 0.86110
# Epoch 39/100
# Learning rate:  0.001
#  - 164s - loss: 0.7186 - acc: 0.8251 - val_loss: 0.8630 - val_acc: 0.8007
#
# Epoch 00039: val_acc did not improve from 0.86110
# Epoch 40/100
# Learning rate:  0.001
#  - 163s - loss: 0.7137 - acc: 0.8285 - val_loss: 0.7248 - val_acc: 0.8501
#
# Epoch 00040: val_acc did not improve from 0.86110
# Epoch 41/100
# Learning rate:  0.001
#  - 164s - loss: 0.7135 - acc: 0.8278 - val_loss: 0.7988 - val_acc: 0.8242
#
# Epoch 00041: val_acc did not improve from 0.86110
# Epoch 42/100
# Learning rate:  0.0005
#  - 162s - loss: 0.6360 - acc: 0.8530 - val_loss: 0.5434 - val_acc: 0.8924
#
# Epoch 00042: val_acc improved from 0.86110 to 0.89240, saving model to cifar10-resnet2-best.h5
# Epoch 43/100
# Learning rate:  0.0005
#  - 162s - loss: 0.6129 - acc: 0.8581 - val_loss: 0.6200 - val_acc: 0.8724
#
# Epoch 00043: val_acc did not improve from 0.89240
# Epoch 44/100
# Learning rate:  0.0005
#  - 163s - loss: 0.6006 - acc: 0.8599 - val_loss: 0.5355 - val_acc: 0.8938
#
# Epoch 00044: val_acc improved from 0.89240 to 0.89380, saving model to cifar10-resnet2-best.h5
# Epoch 45/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5903 - acc: 0.8617 - val_loss: 0.5713 - val_acc: 0.8816
#
# Epoch 00045: val_acc did not improve from 0.89380
# Epoch 46/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5829 - acc: 0.8632 - val_loss: 0.5772 - val_acc: 0.8769
#
# Epoch 00046: val_acc did not improve from 0.89380
# Epoch 47/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5701 - acc: 0.8662 - val_loss: 0.5356 - val_acc: 0.8917
#
# Epoch 00047: val_acc did not improve from 0.89380
# Epoch 48/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5695 - acc: 0.8652 - val_loss: 0.5629 - val_acc: 0.8793
#
# Epoch 00048: val_acc did not improve from 0.89380
# Epoch 49/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5659 - acc: 0.8653 - val_loss: 0.5209 - val_acc: 0.8930
#
# Epoch 00049: val_acc did not improve from 0.89380
# Epoch 50/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5586 - acc: 0.8676 - val_loss: 0.5617 - val_acc: 0.8823
#
# Epoch 00050: val_acc did not improve from 0.89380
# Epoch 51/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5581 - acc: 0.8667 - val_loss: 0.5401 - val_acc: 0.8873
#
# Epoch 00051: val_acc did not improve from 0.89380
# Epoch 52/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5513 - acc: 0.8697 - val_loss: 0.5711 - val_acc: 0.8832
#
# Epoch 00052: val_acc did not improve from 0.89380
# Epoch 53/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5491 - acc: 0.8694 - val_loss: 0.6064 - val_acc: 0.8715
#
# Epoch 00053: val_acc did not improve from 0.89380
# Epoch 54/100
# Learning rate:  0.0005
#  - 164s - loss: 0.5425 - acc: 0.8704 - val_loss: 0.4928 - val_acc: 0.9008
#
# Epoch 00054: val_acc improved from 0.89380 to 0.90080, saving model to cifar10-resnet2-best.h5
# Epoch 55/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5424 - acc: 0.8702 - val_loss: 0.5416 - val_acc: 0.8894
#
# Epoch 00055: val_acc did not improve from 0.90080
# Epoch 56/100
# Learning rate:  0.0005
#  - 164s - loss: 0.5389 - acc: 0.8706 - val_loss: 0.4889 - val_acc: 0.8978
#
# Epoch 00056: val_acc did not improve from 0.90080
# Epoch 57/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5380 - acc: 0.8715 - val_loss: 0.6384 - val_acc: 0.8637
#
# Epoch 00057: val_acc did not improve from 0.90080
# Epoch 58/100
# Learning rate:  0.0005
#  - 164s - loss: 0.5332 - acc: 0.8734 - val_loss: 0.5123 - val_acc: 0.8956
#
# Epoch 00058: val_acc did not improve from 0.90080
# Epoch 59/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5312 - acc: 0.8737 - val_loss: 0.5116 - val_acc: 0.8950
#
# Epoch 00059: val_acc did not improve from 0.90080
# Epoch 60/100
# Learning rate:  0.0005
#  - 164s - loss: 0.5298 - acc: 0.8741 - val_loss: 0.5102 - val_acc: 0.8970
#
# Epoch 00060: val_acc did not improve from 0.90080
# Epoch 61/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5300 - acc: 0.8745 - val_loss: 0.4803 - val_acc: 0.9013
#
# Epoch 00061: val_acc improved from 0.90080 to 0.90130, saving model to cifar10-resnet2-best.h5
# Epoch 62/100
# Learning rate:  0.0002
#  - 163s - loss: 0.4735 - acc: 0.8921 - val_loss: 0.4500 - val_acc: 0.9114
#
# Epoch 00062: val_acc improved from 0.90130 to 0.91140, saving model to cifar10-resnet2-best.h5
# Epoch 63/100
# Learning rate:  0.0002
#  - 163s - loss: 0.4590 - acc: 0.8968 - val_loss: 0.4208 - val_acc: 0.9188
#
# Epoch 00063: val_acc improved from 0.91140 to 0.91880, saving model to cifar10-resnet2-best.h5
# Epoch 64/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4513 - acc: 0.8983 - val_loss: 0.4661 - val_acc: 0.9075
#
# Epoch 00064: val_acc did not improve from 0.91880
# Epoch 65/100
# Learning rate:  0.0002
#  - 165s - loss: 0.4466 - acc: 0.8983 - val_loss: 0.4147 - val_acc: 0.9206
#
# Epoch 00065: val_acc improved from 0.91880 to 0.92060, saving model to cifar10-resnet2-best.h5
# Epoch 66/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4414 - acc: 0.9014 - val_loss: 0.4599 - val_acc: 0.9102
#
# Epoch 00066: val_acc did not improve from 0.92060
# Epoch 67/100
# Learning rate:  0.0002
#  - 165s - loss: 0.4334 - acc: 0.9021 - val_loss: 0.4849 - val_acc: 0.9026
#
# Epoch 00067: val_acc did not improve from 0.92060
# Epoch 68/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4299 - acc: 0.9035 - val_loss: 0.4494 - val_acc: 0.9129
#
# Epoch 00068: val_acc did not improve from 0.92060
# Epoch 69/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4241 - acc: 0.9039 - val_loss: 0.4375 - val_acc: 0.9149
#
# Epoch 00069: val_acc did not improve from 0.92060
# Epoch 70/100
# Learning rate:  0.0002
#  - 163s - loss: 0.4235 - acc: 0.9054 - val_loss: 0.4393 - val_acc: 0.9163
#
# Epoch 00070: val_acc did not improve from 0.92060
# Epoch 71/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4174 - acc: 0.9060 - val_loss: 0.4355 - val_acc: 0.9140
#
# Epoch 00071: val_acc did not improve from 0.92060
# Epoch 72/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4174 - acc: 0.9051 - val_loss: 0.4165 - val_acc: 0.9189
#
# Epoch 00072: val_acc did not improve from 0.92060
# Epoch 73/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4117 - acc: 0.9075 - val_loss: 0.4113 - val_acc: 0.9194
#
# Epoch 00073: val_acc did not improve from 0.92060
# Epoch 74/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4071 - acc: 0.9084 - val_loss: 0.4385 - val_acc: 0.9144
#
# Epoch 00074: val_acc did not improve from 0.92060
# Epoch 75/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4056 - acc: 0.9071 - val_loss: 0.4281 - val_acc: 0.9203
#
# Epoch 00075: val_acc did not improve from 0.92060
# Epoch 76/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4065 - acc: 0.9077 - val_loss: 0.4141 - val_acc: 0.9219
#
# Epoch 00076: val_acc improved from 0.92060 to 0.92190, saving model to cifar10-resnet2-best.h5
# Epoch 77/100
# Learning rate:  0.0002
#  - 164s - loss: 0.4021 - acc: 0.9087 - val_loss: 0.4173 - val_acc: 0.9169
#
# Epoch 00077: val_acc did not improve from 0.92190
# Epoch 78/100
# Learning rate:  0.0002
#  - 164s - loss: 0.3977 - acc: 0.9099 - val_loss: 0.4324 - val_acc: 0.9172
#
# Epoch 00078: val_acc did not improve from 0.92190
# Epoch 79/100
# Learning rate:  0.0002
#  - 164s - loss: 0.3989 - acc: 0.9098 - val_loss: 0.4728 - val_acc: 0.9081
#
# Epoch 00079: val_acc did not improve from 0.92190
# Epoch 80/100
# Learning rate:  0.0002
#  - 164s - loss: 0.3960 - acc: 0.9101 - val_loss: 0.4699 - val_acc: 0.9070
#
# Epoch 00080: val_acc did not improve from 0.92190
# Epoch 81/100
# Learning rate:  0.0002
#  - 164s - loss: 0.3936 - acc: 0.9105 - val_loss: 0.4466 - val_acc: 0.9109
#
# Epoch 00081: val_acc did not improve from 0.92190
# Epoch 82/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3730 - acc: 0.9170 - val_loss: 0.3897 - val_acc: 0.9245
#
# Epoch 00082: val_acc improved from 0.92190 to 0.92450, saving model to cifar10-resnet2-best.h5
# Epoch 83/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3657 - acc: 0.9190 - val_loss: 0.3964 - val_acc: 0.9230
#
# Epoch 00083: val_acc did not improve from 0.92450
# Epoch 84/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3614 - acc: 0.9211 - val_loss: 0.4026 - val_acc: 0.9238
#
# Epoch 00084: val_acc did not improve from 0.92450
# Epoch 85/100
# Learning rate:  0.0001
#  - 164s - loss: 0.3583 - acc: 0.9214 - val_loss: 0.3972 - val_acc: 0.9265
#
# Epoch 00085: val_acc improved from 0.92450 to 0.92650, saving model to cifar10-resnet2-best.h5
# Epoch 86/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3525 - acc: 0.9241 - val_loss: 0.4100 - val_acc: 0.9248
#
# Epoch 00086: val_acc did not improve from 0.92650
# Epoch 87/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3538 - acc: 0.9226 - val_loss: 0.4151 - val_acc: 0.9226
#
# Epoch 00087: val_acc did not improve from 0.92650
# Epoch 88/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3519 - acc: 0.9236 - val_loss: 0.3856 - val_acc: 0.9264
#
# Epoch 00088: val_acc did not improve from 0.92650
# Epoch 89/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3474 - acc: 0.9246 - val_loss: 0.3977 - val_acc: 0.9266
#
# Epoch 00089: val_acc improved from 0.92650 to 0.92660, saving model to cifar10-resnet2-best.h5
# Epoch 90/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3441 - acc: 0.9257 - val_loss: 0.3998 - val_acc: 0.9239
#
# Epoch 00090: val_acc did not improve from 0.92660
# Epoch 91/100
# Learning rate:  0.0001
#  - 165s - loss: 0.3447 - acc: 0.9244 - val_loss: 0.3891 - val_acc: 0.9223
#
# Epoch 00091: val_acc did not improve from 0.92660
# Epoch 92/100
# Learning rate:  3e-05
#  - 165s - loss: 0.3291 - acc: 0.9310 - val_loss: 0.3899 - val_acc: 0.9266
#
# Epoch 00092: val_acc did not improve from 0.92660
# Epoch 93/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3263 - acc: 0.9314 - val_loss: 0.3801 - val_acc: 0.9294
#
# Epoch 00093: val_acc improved from 0.92660 to 0.92940, saving model to cifar10-resnet2-best.h5
# Epoch 94/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3230 - acc: 0.9335 - val_loss: 0.3772 - val_acc: 0.9291
#
# Epoch 00094: val_acc did not improve from 0.92940
# Epoch 95/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3236 - acc: 0.9327 - val_loss: 0.3927 - val_acc: 0.9266
#
# Epoch 00095: val_acc did not improve from 0.92940
# Epoch 96/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3219 - acc: 0.9323 - val_loss: 0.3918 - val_acc: 0.9273
#
# Epoch 00096: val_acc did not improve from 0.92940
# Epoch 97/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3243 - acc: 0.9322 - val_loss: 0.3839 - val_acc: 0.9291
#
# Epoch 00097: val_acc did not improve from 0.92940
# Epoch 98/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3230 - acc: 0.9312 - val_loss: 0.3761 - val_acc: 0.9309
#
# Epoch 00098: val_acc improved from 0.92940 to 0.93090, saving model to cifar10-resnet2-best.h5
# Epoch 99/100
# Learning rate:  3e-05
#  - 164s - loss: 0.3180 - acc: 0.9341 - val_loss: 0.3769 - val_acc: 0.9298
#
# Epoch 00099: val_acc did not improve from 0.93090
# Epoch 100/100
# Learning rate:  3e-05
#  - 163s - loss: 0.3160 - acc: 0.9337 - val_loss: 0.3944 - val_acc: 0.9268
#
# Epoch 00100: val_acc did not improve from 0.93090

# %%
model.load_weights(fname) # Continue from previous run with model val acc 0.93140
# Fit the model on the batches generated by datagen.flow().
hist2 = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=2*x_train.shape[0]//batch_size,
                    validation_data=(x_test, y_test),
                    initial_epoch=100, epochs=120, verbose=2, callbacks=callbacks)
# Out:
# Epoch 101/120
# Learning rate:  3e-05
#  - 161s - loss: 0.3027 - acc: 0.9375 - val_loss: 0.3777 - val_acc: 0.9301
#
# Epoch 00101: val_acc did not improve from 0.93140
# Epoch 102/120
# Learning rate:  3e-05
#  - 161s - loss: 0.3068 - acc: 0.9362 - val_loss: 0.3899 - val_acc: 0.9274
#
# Epoch 00102: val_acc did not improve from 0.93140
# Epoch 103/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3051 - acc: 0.9365 - val_loss: 0.3854 - val_acc: 0.9264
#
# Epoch 00103: val_acc did not improve from 0.93140
# Epoch 104/120
# Learning rate:  3e-05
#  - 161s - loss: 0.3038 - acc: 0.9373 - val_loss: 0.3818 - val_acc: 0.9279
#
# Epoch 00104: val_acc did not improve from 0.93140
# Epoch 105/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3007 - acc: 0.9381 - val_loss: 0.3988 - val_acc: 0.9243
#
# Epoch 00105: val_acc did not improve from 0.93140
# Epoch 106/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3024 - acc: 0.9363 - val_loss: 0.3953 - val_acc: 0.9249
#
# Epoch 00106: val_acc did not improve from 0.93140
# Epoch 107/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3023 - acc: 0.9369 - val_loss: 0.3887 - val_acc: 0.9275
#
# Epoch 00107: val_acc did not improve from 0.93140
# Epoch 108/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2988 - acc: 0.9390 - val_loss: 0.3817 - val_acc: 0.9289
#
# Epoch 00108: val_acc did not improve from 0.93140
# Epoch 109/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3020 - acc: 0.9363 - val_loss: 0.3792 - val_acc: 0.9278
#
# Epoch 00109: val_acc did not improve from 0.93140
# Epoch 110/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2992 - acc: 0.9375 - val_loss: 0.3861 - val_acc: 0.9263
#
# Epoch 00110: val_acc did not improve from 0.93140
# Epoch 111/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2991 - acc: 0.9376 - val_loss: 0.3807 - val_acc: 0.9284
#
# Epoch 00111: val_acc did not improve from 0.93140
# Epoch 112/120
# Learning rate:  3e-05
#  - 160s - loss: 0.3003 - acc: 0.9377 - val_loss: 0.3825 - val_acc: 0.9293
#
# Epoch 00112: val_acc did not improve from 0.93140
# Epoch 113/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2966 - acc: 0.9389 - val_loss: 0.3870 - val_acc: 0.9289
#
# Epoch 00113: val_acc did not improve from 0.93140
# Epoch 114/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2972 - acc: 0.9378 - val_loss: 0.3889 - val_acc: 0.9278
#
# Epoch 00114: val_acc did not improve from 0.93140
# Epoch 115/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2964 - acc: 0.9385 - val_loss: 0.3904 - val_acc: 0.9272
#
# Epoch 00115: val_acc did not improve from 0.93140
# Epoch 116/120
# Learning rate:  3e-05
#  - 161s - loss: 0.2951 - acc: 0.9386 - val_loss: 0.3934 - val_acc: 0.9271
#
# Epoch 00116: val_acc did not improve from 0.93140
# Epoch 117/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2945 - acc: 0.9385 - val_loss: 0.3837 - val_acc: 0.9291
#
# Epoch 00117: val_acc did not improve from 0.93140
# Epoch 118/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2906 - acc: 0.9400 - val_loss: 0.3909 - val_acc: 0.9274
#
# Epoch 00118: val_acc did not improve from 0.93140
# Epoch 119/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2935 - acc: 0.9391 - val_loss: 0.3840 - val_acc: 0.9279
#
# Epoch 00119: val_acc did not improve from 0.93140
# Epoch 120/120
# Learning rate:  3e-05
#  - 160s - loss: 0.2959 - acc: 0.9388 - val_loss: 0.3883 - val_acc: 0.9268
#
# Epoch 00120: val_acc did not improve from 0.93140

# %%
#hist.history = {hist.history[k]+hist2.history[k] for k in hist.history}
hist = hist2 # Show history after update only

# %% [markdown]
# # Results

# %%
plt.plot(hist.history['val_acc'],label='val_acc')
plt.plot(hist.history['acc'],label='acc')
plt.legend()
plt.show()

# %%
np.max(hist.history['val_acc'])
# Out:
# 0.9301
